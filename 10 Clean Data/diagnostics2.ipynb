# %%
import pandas as pd
arrests2 = pd.read_csv('/Users/clarissaache/Documents/Data+/SToPAGetDurhamData/cleaned_arrests_table_new.csv', low_memory=False)
arrests = pd.read_csv(
    "/Users/clarissaache/Documents/Data+/SToPAGetDurhamData/10 Clean Data/clean02.csv"
)
# Out:
# /Users/clarissaache/opt/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (55,61,66,67,69,70,71,72,75,77) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
arrests2.loc[arrests2['narrative'].isna()]
# Out:
#        Unnamed: 0                agencyname                         name  \
# 0               1  Durham Police Department       MORGAN, ALTON REGINALD
# 1               2  Durham Police Department        MURPHY, BRYCE CALEB E
# 2               3  Durham Police Department      GABRIEL, GARCIA MENDOZA
# 3               4  Durham Police Department  BROWN-ALLEN, TESHONNA LANEA
# 4               5  Durham Police Department          BILLINGS, LORENZARA
# ...           ...                       ...                          ...
# 18703       18704  Durham Police Department       SLADE, RODERICK LESLIE
# 18704       18705  Durham Police Department    STARKS, SHOMONIQUE PORCHE
# 18705       18706  Durham Police Department          PARRISH, ANGEL LYNN
# 18706       18707  Durham Police Department         CAINE, DWIGHT GLOVER
# 18707       18708                       NaN         PERKINSON, JULIE KAY
#
#         datetimeofarrest                                 file  arrestnumber  \
# ...

# %%
cols1 = [
    "arrestnumber",
    "charge1",
    "charge2",
    "charge3",
    "charge4",
    "charge5",
    "charge6",
    "charge7",
    "charge8",
    "charge9",
]

# %% [markdown]
# # Second pages only

# %%
second = pd.read_csv('/Users/clarissaache/Documents/Data+/SToPAGetDurhamData/00 Raw Data/second_page_name.csv', low_memory=False)

second = second.loc[:, second.columns != "Unnamed: 0"]
second.shape
# Out:
# (1174, 135)

# %%
extra_pages = second[second.duplicated('arrestnumber')]
extra_pages.head()
# Out:
#                               name  \
# 186  CAMPBELL, CHRISTOPHER STAPHON
# 191     WILLIAMSON, DEVONTE LAMONT
# 195           MARTIN, WANDA YVETTE
# 196           MARTIN, WANDA YVETTE
# 226      HIGGINS, KEIJUARN MARQUIS
#
#                                             charge4 charge4type  \
# 186      B&e-vehicle, Rr Cars, Other Motor Vehicles         Fel
# 191  Possession Of Firearms  Etc By FelonProhibited         Fel
# 195       Forgery Or Possess CounterfeitInstruments         Fel
# 196                     Exploit Disable Elder Trust         Fel
# 226                    Fail To Appear-release Order         Fel
#
#     charge4IBRcode charge4statutenumber charge4warrantdate  \
# 186            23F                14-56         08/01/2021
# 191            520             14-415.1         08/02/2021
# 195            250            14-119(A)         06/11/2020
# 196            26A          14-112.2(B)         06/01/2020
# 226            90Z        15A-305(B)(2)         07/27/2021
#
# ...

# %%
second.drop(extra_pages.index)
# Out:
#                                      name  \
# 0                  ROGERS, DERRICK TYRONE
# 1                  SALES, JAIMOND AZAVIER
# 2                    CHESSON, OGLA STELLA
# 3               GREEN, KEYSHAWN LAFAYETTE
# 4                    CLARK, ERICA LATONYA
# ...                                   ...
# 1147               WILLIAMS, LAMARIS DEON
# 1148  GRAVES, PRESTON DELANO          III
# 1149                JOHNSON, CARL VINCENT
# 1166               SHARKEY, RACHAEL MARIE
# 1173                 COOLEY, DOMINIC QUIN
#
#                                             charge4 charge4type  \
# 0            Warrant Service For Other Jurisdiction        Misd
# 1                      Fail To Appear-release Order        Misd
# 2                  Conspiracy To Commit Misdemeanor        Misd
# 3          Breaking And Entering Building  (felony)         Fel
# 4            Warrant Service For Other Jurisdiction         NaN
# ...                                             ...         ...
# ...

# %%
arrests[arrests[['arrestnumber', 'casenumber']].duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
full = arrests.merge(second, on=['arrestnumber', 'casenumber'], how='left', validate='m:m')

# %%
print(full.shape)
# Out:
# (17225, 238)

# %%
full[full['arrestnumber']==306999][cols1]
# Out:
#    arrestnumber                                   charge1  \
# 6        306999  Assault Law Enforcement Or State Officer
# 7        306999  Assault Law Enforcement Or State Officer
#
#                                      charge2              charge3  \
# 6  Receiving Or Transferring Stolen Vehicles  Probation Violation
# 7  Receiving Or Transferring Stolen Vehicles  Probation Violation
#
#                charge4 charge5 charge6 charge7 charge8 charge9
# 6  Probation Violation     NaN     NaN     NaN     NaN     NaN
# 7  Probation Violation     NaN     NaN     NaN     NaN     NaN
