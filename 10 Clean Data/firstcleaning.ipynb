# %%
import pandas as pd
import numpy as np
import re

# %%
#reading in files
arrests = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/arrests_table.csv")
redone_arrests = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/redone_arrests_table.csv")
second_page = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/2ndpagearrests_table.csv")
missing_first = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/missing_arrests.csv")
missing_second = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/2ndpagearrests_missing_table.csv")
missing2_first = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/intermediate_missing2_arrests.csv", index_col = [0])
missing2_second = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/2ndpagearrests_missing2_table.csv", index_col = [0])
missing3_first = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/missing3_arrests.csv", index_col = [0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-19db0ebd7665> in <module>
#       1 #reading in files
# ----> 2 arrests = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/arrests_table.csv")
#       3 redone_arrests = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/redone_arrests_table.csv")
#       4 second_page = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/2ndpagearrests_table.csv")
#       5 missing_first = pd.read_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/missing_arrests.csv")
#
# ...

# %%
#got rid of first column with incorrect indices
arrests = arrests.loc[:, arrests.columns != "Unnamed: 0"]
redone_arrests = redone_arrests.loc[:, redone_arrests.columns != "Unnamed: 0"]
second_page = second_page.loc[:, second_page.columns != "Unnamed: 0"]
missing_first = missing_first.loc[:, missing_first.columns != "Unnamed: 0"]
missing_second = missing_second.loc[:, missing_second.columns != "Unnamed: 0"]
missing2_first = missing2_first.loc[:, missing2_first.columns != "Unnamed: 0"]
missing2_second = missing2_second.loc[:, missing2_second.columns != "Unnamed: 0"]

missing2_first.head()
# Out:
#                        agencyname                                  name  \
# 1  Durham Police Department\r\r\n           AUCOIN, LAUREN NICOLE\r\r\n
# 2  Durham Police Department\r\r\n                 SADLER, KRISTIN\r\r\n
# 3  Durham Police Department\r\r\n  JUAREZ CHAVEZ, MARIA ALEJANDRA\r\r\n
# 4  Durham Police Department\r\r\n           BENNETT, COREY LAMONT\r\r\n
# 5  Durham Police Department\r\r\n            SIMMS, PATRICK WAYNE\r\r\n
#
#           datetimeofarrest                         file  arrestnumber  \
# 1  07/18/2020  20:23\r\r\n  missing2/arrests0000001.pdf  319156\r\r\n
# 2  07/18/2020  22:43\r\r\n  missing2/arrests0000002.pdf  319158\r\r\n
# 3  07/22/2020  22:54\r\r\n  missing2/arrests0000003.pdf  319229\r\r\n
# 4  07/25/2020  03:38\r\r\n  missing2/arrests0000004.pdf  319260\r\r\n
# 5  07/23/2020  16:58\r\r\n  missing2/arrests0000005.pdf  319245\r\r\n
#
#           scars_tattoes_bodymarkings_etc          birthday       age     race  \
# ...

# %%
#setting the default to show all rows
pd.set_option("display.max_row", 101)
#looking at where dtypes are int64, these should be moved to the end
missing3_first.dtypes[missing3_first.dtypes == "int64"]

# %%
#moving certain columns to the back of dataframe so the loop to clean out "/r/r/n" works
last_column = missing3_first.pop("arrestnumber")
missing3_first.insert(101, 'arrestnumber', last_column)
second_last_column = missing3_first.pop("age")
missing3_first.insert(101, 'age', second_last_column)
last_column = missing3_first.pop("casenumber")
missing3_first.insert(101, 'casenumber', last_column)
last_column = missing3_first.pop("charge1counts")
missing3_first.insert(101, 'charge1counts', last_column)
missing3_first.head()
# Out:
#                  agencyname                              name  \
# 1  Durham Police Department               BELLER, ANDRE IMANI
# 2  Durham Police Department  CHERRY, JAMES ALFRED          JR
# 3  Durham Police Department            DEWITT, WADE JEFFERSON
# 4  Durham Police Department             FUENTES, ROBIN UBALDO
# 5  Durham Police Department                SMITH, NASIR AHMAD
#
#     datetimeofarrest                                     file  \
# 1  07/29/2020  08:43  00 Raw Data/missing3/arrests0000001.pdf
# 2  07/28/2020  07:50  00 Raw Data/missing3/arrests0000002.pdf
# 3  07/27/2020  06:50  00 Raw Data/missing3/arrests0000003.pdf
# 4  07/26/2020  05:04  00 Raw Data/missing3/arrests0000004.pdf
# 5  08/26/2020  16:39  00 Raw Data/missing3/arrests0000005.pdf
#
#                       scars_tattoes_bodymarkings_etc    birthday race sex  \
# 1                             TATT      HAND / STARS  01/11/1986    B   M
# ...

# %%
#removing all instances of "\r\r\n". Outer loop iterates over each column in the dataset and inner
# loop iterates over each row within the specified column to delete the unnecessary string
#for j in range(len(second_page.columns)):
z = len(missing3_first.columns) -4
z
for k in range(z):
    for i in range(len(missing3_first['name'])):
        missing3_first.iloc[i, k] = missing3_first.iloc[i, k].replace("\r\r\n", "")

#arrests.head()

# %%
#saving new table in csv file and to the github


#clean01 = arrests.to_csv("/Users/morganbernstein/Desktop/DATA+/SToPAGetDurhamData/10 Clean Data/clean01.csv")
#redone_clean01 = redone_arrests.to_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/10 Clean Data/redone_clean01.csv")
#second_page_clean = second_page.to_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/00 Raw Data/second_page_name.csv")
#missing_second_page_clean = missing_second.to_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/10 Clean Data/clean_missing_2ndpages.csv")
#missing_first_page_clean = missing_first.to_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/10 Clean Data/clean_missing_1stpages.csv")
#missing_second_page_clean = missing2_second.to_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/10 Clean Data/clean_missing2_2ndpages.csv")
#missing_first_page_clean = missing2_first.to_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/10 Clean Data/clean_missing2_1stpages.csv")

#missing3_first_page_clean = missing3_first.to_csv("/Users/Benji/Dropbox/PC/Documents/R/SToPAGetDurhamData3/10 Clean Data/clean_missing3_1stpages.csv")
